# %% [markdown]
# # **CNN assignment**(Do read the note at the end)

# %% [markdown]
# Description: Here we are going to use CNN to classify images of elephants,tigers,cheetah's and crocodiles. Basically multiclass classificiation using CNN.

# %% [markdown]
# **Q.1** Import all required modules

# %%
#Your code here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing import image_dataset_from_directory
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Q.2** Load data using image_dataset_from_directory(https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image_dataset_from_directory)

# %%
data=tf.keras.preprocessing.image_dataset_from_directory(
    '/content/drive/My Drive/LS24-Machine Learning/data',
    labels='inferred',
    label_mode='int',
    class_names=['Cheetah','Crocodile','Elephants','Tiger'],
    color_mode='rgb',
    image_size=(128,128),
    shuffle=True,
    seed=123,
    batch_size=32
)
# Out:
# Found 1658 files belonging to 4 classes.

# %% [markdown]
# *   Since data object is not iterable,we will create a nummpy iterator for data.
# *   Then use batch to iterate through our data

# %%
data_iterator=data.as_numpy_iterator()

# %%
batch=data_iterator.next()

# %% [markdown]
# Run the below code and batch code 2-3 times to visualise the labels given to different animals.

# %%
fig,ax=plt.subplots(ncols=4,figsize=(20,20))
for idx,img in enumerate(batch[0][:4]):
  ax[idx].imshow(img.astype(int))
  ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# **Q.3** Map the data such that all pixel values lie between 0 and 1 using the **lambda function**

# %%
def normalize_image(image, label):
    image=tf.cast(image, tf.float32)/255.0
    return image,label
data=data.map(normalize_image)

# %% [markdown]
# **Q.4** Split the data into train set and test set(and validation set if needed) using **data.take**(https://www.geeksforgeeks.org/tensorflow-js-tf-data-dataset-class-take-method/) and **data.skip**(https://www.geeksforgeeks.org/tensorflow-js-tf-data-dataset-skip-method/)

# %%
#Your code here
data_size=len(data)
train_size=int(data_size*0.8)
test_size=data_size-train_size
data_train=data.take(train_size)
data_test=data.skip(train_size)

# %% [markdown]
# **Creating the model**

# %% [markdown]
# **Q.5** Write code to create CNN model including fully connected layers with softmax as final layer.

# %%
model=keras.Sequential([
    keras.Input(shape=(128,128,3)),
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(4, activation='softmax'),
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 63, 63, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 30, 30, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 14, 14, 128)       0
#  g2D)
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 128)               3211392
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 3305156 (12.61 MB)
# Trainable params: 3305156 (12.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Q.6** Compile your model

# %%
model.compile(loss = keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    optimizer = keras.optimizers.Adam(learning_rate=0.0001),
    metrics = ['accuracy'])

# %% [markdown]
# **Q.7** Fit your model with train set and make sure to keep **less epochs**(10-15) as the dataset size is very large.

# %%
model.fit(data_train,epochs=30,validation_data=data_test, verbose=2)
# Out:
# Epoch 1/30
# 41/41 - 183s - loss: 1.3323 - accuracy: 0.3369 - val_loss: 1.2371 - val_accuracy: 0.4855 - 183s/epoch - 4s/step
# Epoch 2/30
# 41/41 - 24s - loss: 1.1796 - accuracy: 0.4764 - val_loss: 1.0636 - val_accuracy: 0.5578 - 24s/epoch - 577ms/step
# Epoch 3/30
# 41/41 - 25s - loss: 1.0385 - accuracy: 0.5747 - val_loss: 0.9784 - val_accuracy: 0.6012 - 25s/epoch - 612ms/step
# Epoch 4/30
# 41/41 - 23s - loss: 0.9487 - accuracy: 0.6090 - val_loss: 0.9460 - val_accuracy: 0.5867 - 23s/epoch - 553ms/step
# Epoch 5/30
# 41/41 - 24s - loss: 0.8471 - accuracy: 0.6730 - val_loss: 0.8441 - val_accuracy: 0.6590 - 24s/epoch - 579ms/step
# Epoch 6/30
# 41/41 - 24s - loss: 0.7824 - accuracy: 0.7050 - val_loss: 0.8105 - val_accuracy: 0.6821 - 24s/epoch - 584ms/step
# Epoch 7/30
# 41/41 - 32s - loss: 0.7483 - accuracy: 0.7218 - val_loss: 0.7216 - val_accuracy: 0.7457 - 32s/epoch - 783ms/step
# Epoch 8/30
# 41/41 - 24s - loss: 0.6777 - accuracy: 0.7546 - val_loss: 0.6314 - val_accuracy: 0.7659 - 24s/epoch - 575ms/step
# Epoch 9/30
# 41/41 - 24s - loss: 0.6193 - accuracy: 0.7668 - val_loss: 0.6409 - val_accuracy: 0.7890 - 24s/epoch - 583ms/step
# Epoch 10/30
# 41/41 - 24s - loss: 0.5786 - accuracy: 0.7980 - val_loss: 0.7393 - val_accuracy: 0.7052 - 24s/epoch - 587ms/step
# Epoch 11/30
# 41/41 - 32s - loss: 0.5700 - accuracy: 0.7912 - val_loss: 0.6403 - val_accuracy: 0.7572 - 32s/epoch - 792ms/step
# Epoch 12/30
# 41/41 - 23s - loss: 0.5157 - accuracy: 0.8155 - val_loss: 0.6053 - val_accuracy: 0.7948 - 23s/epoch - 573ms/step
# Epoch 13/30
# 41/41 - 24s - loss: 0.5148 - accuracy: 0.8087 - val_loss: 0.6261 - val_accuracy: 0.7746 - 24s/epoch - 579ms/step
# Epoch 14/30
# 41/41 - 24s - loss: 0.4930 - accuracy: 0.8201 - val_loss: 0.5307 - val_accuracy: 0.8266 - 24s/epoch - 585ms/step
# Epoch 15/30
# 41/41 - 23s - loss: 0.4356 - accuracy: 0.8575 - val_loss: 0.5947 - val_accuracy: 0.7659 - 23s/epoch - 571ms/step
# Epoch 16/30
# 41/41 - 32s - loss: 0.4111 - accuracy: 0.8681 - val_loss: 0.6070 - val_accuracy: 0.7630 - 32s/epoch - 786ms/step
# Epoch 17/30
# 41/41 - 23s - loss: 0.3919 - accuracy: 0.8750 - val_loss: 0.4595 - val_accuracy: 0.8439 - 23s/epoch - 564ms/step
# Epoch 18/30
# 41/41 - 23s - loss: 0.3684 - accuracy: 0.8811 - val_loss: 0.4550 - val_accuracy: 0.8295 - 23s/epoch - 567ms/step
# Epoch 19/30
# 41/41 - 22s - loss: 0.3415 - accuracy: 0.8902 - val_loss: 0.4983 - val_accuracy: 0.8237 - 22s/epoch - 536ms/step
# Epoch 20/30
# 41/41 - 23s - loss: 0.3314 - accuracy: 0.8941 - val_loss: 0.4757 - val_accuracy: 0.8382 - 23s/epoch - 563ms/step
# Epoch 21/30
# 41/41 - 32s - loss: 0.3049 - accuracy: 0.9085 - val_loss: 0.4467 - val_accuracy: 0.8555 - 32s/epoch - 779ms/step
# Epoch 22/30
# 41/41 - 23s - loss: 0.2924 - accuracy: 0.9078 - val_loss: 0.4479 - val_accuracy: 0.8439 - 23s/epoch - 563ms/step
# Epoch 23/30
# 41/41 - 32s - loss: 0.2546 - accuracy: 0.9375 - val_loss: 0.3945 - val_accuracy: 0.8699 - 32s/epoch - 785ms/step
# Epoch 24/30
# 41/41 - 23s - loss: 0.2319 - accuracy: 0.9345 - val_loss: 0.3924 - val_accuracy: 0.8786 - 23s/epoch - 569ms/step
# Epoch 25/30
# 41/41 - 32s - loss: 0.2483 - accuracy: 0.9306 - val_loss: 0.3901 - val_accuracy: 0.8671 - 32s/epoch - 782ms/step
# Epoch 26/30
# 41/41 - 23s - loss: 0.2168 - accuracy: 0.9360 - val_loss: 0.3672 - val_accuracy: 0.8728 - 23s/epoch - 566ms/step
# Epoch 27/30
# 41/41 - 24s - loss: 0.1955 - accuracy: 0.9512 - val_loss: 0.3676 - val_accuracy: 0.8815 - 24s/epoch - 577ms/step
# Epoch 28/30
# 41/41 - 24s - loss: 0.1804 - accuracy: 0.9505 - val_loss: 0.3574 - val_accuracy: 0.8786 - 24s/epoch - 583ms/step
# Epoch 29/30
# 41/41 - 23s - loss: 0.1576 - accuracy: 0.9688 - val_loss: 0.3695 - val_accuracy: 0.8642 - 23s/epoch - 568ms/step
# Epoch 30/30
# 41/41 - 24s - loss: 0.1498 - accuracy: 0.9665 - val_loss: 0.3439 - val_accuracy: 0.8699 - 24s/epoch - 584ms/step

# %% [markdown]
# **Q.8** Test your code with test set

# %%
loss,accuracy=model.evaluate(data_test,verbose=2)
# Out:
# 11/11 - 12s - loss: 0.3360 - accuracy: 0.8699 - 12s/epoch - 1s/step

# %%
# Do not change this code
if accuracy>=0.85:
  print("Congratulations, CNN assignment complete!!")
else:
  print("Try again, not enough accuracy")
# Out:
# Congratulations, CNN assignment complete!!

# %% [markdown]
# **Note: 1. Many of you will get very high train accuracy but low test accuracy. This is called overfitting, this can be solved by increasing the train set size. If your getting low accuracy for both train and test, modify your layers in the model.**
#
# **2.Do use T4GPU.Ideally your first epoch will take quite sometime and rest of the epochs will be faster but if all your epochs are taking a lot of time, try starting a new gpu session(open a new gmail account and open colab on that) because your free gpu might have exhausted itself.**
#
# **3.Other than that everything should be fine, happy learning!!**
